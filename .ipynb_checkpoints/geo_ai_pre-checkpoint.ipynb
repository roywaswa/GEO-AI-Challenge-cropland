# %% [markdown]
# # GEO-AI Challenge for Cropland Mapping by ITU

# %% [markdown]
# ## Google Earth Engine

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import ee
import geemap
import matplotlib.pyplot as plt
import seaborn as sns
import contextily as cx
import plotly.express as px

sns.set_style('whitegrid')
sns.set_palette('husl')

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ilar16FEZs-mHUc8RDMA-0oIHlWLVntqruDCHYnRnyY&tc=5ZUw9L4RmZ5Se2veK3ydR7HSdN6W1ZkuwM2cQeAfcf0&cc=k2F0kiDyA4vysDpws8mrFzieagLJPeMa9-TSQ-nL5eM>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ilar16FEZs-mHUc8RDMA-0oIHlWLVntqruDCHYnRnyY&tc=5ZUw9L4RmZ5Se2veK3ydR7HSdN6W1ZkuwM2cQeAfcf0&cc=k2F0kiDyA4vysDpws8mrFzieagLJPeMa9-TSQ-nL5eM</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
ee.Initialize()

# %% [markdown]
# ## FUNCTION DEFINITIONS

# %%
def determine_country(lat, lon) -> str:
  point = ee.Geometry.Point(lon, lat)
  country = ee.FeatureCollection("FAO/GAUL_SIMPLIFIED_500m/2015/level0").filterBounds(point).first().get('ADM0_NAME').getInfo()
  print(country)
  return str(country)

# %%
def mask_s2_clouds(image):
  qa = image.select('QA60')
  # Bits 10 and 11 are clouds and cirrus, respectively.
  cloudBitMask = 1 << 10
  cirrusBitMask = 1 << 11
  # Both flags should be set to zero, indicating clear conditions.
  mask = qa.bitwiseAnd(cloudBitMask).eq(0) and (qa.bitwiseAnd(cirrusBitMask).eq(0))
  return image.updateMask(mask).divide(10000)

# %% [markdown]
# ## DATA PROCESSING

# %%
train_data = pd.read_csv('data/Train.csv', index_col='ID')
test_data = pd.read_csv('data/Test.csv', index_col='ID')

# %%
train_features = train_data.columns.drop('Target')
target = train_data['Target']
features = pd.concat([train_data[train_features], test_data])

# %%
import concurrent.futures as cf

def determine_country_parallel(x):
  lat, lon = x['Lat'], x['Lon']
  return determine_country(lat, lon)

with cf.ThreadPoolExecutor(12) as executor:
  results = list(executor.map(determine_country_parallel, features.to_dict('records')))

features['Country'] = results
# Out:
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# SudanSudan
#
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)Afghanistan
#
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# SudanAfghanistan
#
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# AfghanistanAfghanistan
#
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# AfghanistanAfghanistan
#
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)Iran  (Islamic Republic of)
#
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# AfghanistanAfghanistan
#
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Afghanistan
# SudanSudan
#
# Sudan
# Sudan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Sudan
# Sudan
# Sudan
# Iran  (Islamic Republic of)
# Afghanistan
# Sudan
# Iran  (Islamic Republic of)
# Sudan
# Afghanistan
# Sudan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Iran  (Islamic Republic of)
# Afghanistan
# Afghanistan
# Sudan
# Afghanistan
# Afghanistan
# Iran  (Islamic Republic of)
# Iran  (Islamic Republic of)
# Sudan
# Sudan

# %%
features_gdf = gpd.GeoDataFrame(features, crs='EPSG:4326', geometry=gpd.points_from_xy(features.Lon, features.Lat))
features_gdf.to_file('data/features.geojson', driver='GeoJSON', index=False, overwrite=True)

# %% [markdown]
# ## EARTH ENGINE

# %%
Map = geemap.Map()

# %%
# get extent of the features
extent = features_gdf[features_gdf['Country']=='Sudan'].total_bounds
roi = ee.Geometry.Rectangle(extent.tolist()).buffer(10000)
sudan_points = ee.Geometry.MultiPoint(features_gdf[features_gdf['Country']=='Sudan'][['Lon', 'Lat']].values.tolist())
Map.addLayer(roi, {}, 'ROI')
Map.addLayer(sudan_points, {}, 'Features')

# %%
dataset = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')\
            .filterDate('2022-04-01', '2022-05-31')\
            .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE',20))\
            .map(mask_s2_clouds)

visualization = {
  'min': 0.0,
  'max': 0.3,
  'bands': ['B4', 'B3', 'B2'],
}
Map.addLayer(dataset.mean(), visualization, 'Sentinel-2 Harmonized')

# %%
Map.centerObject(roi, 9)
Map
# Out:
# Map(center=[14.341489314084608, 33.35031449982657], controls=(WidgetControl(options=['position', 'transparent_…

# %%
def get_mean_values(lat, lon):
  point = ee.Geometry.Point(lon, lat)
  mean_dict = dataset.mean().reduceRegion(ee.Reducer.mean(), point, 10).getInfo()
  return mean_dict

# %%
with cf.ThreadPoolExecutor() as executor:
  results = list(executor.map(get_mean_values, features_gdf['Lat'], features_gdf['Lon']))
bands = ['B2', 'B3', 'B4', 'B8']
for band in bands:
  features_gdf[band] = [x[band] for x in results]

# %%
features_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 3000 entries, ID_SJ098E7S2SY9 to ID_FKB2YZ2BXZ0Z
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Lat       3000 non-null   float64
#  1   Lon       3000 non-null   float64
#  2   Country   3000 non-null   object
#  3   geometry  3000 non-null   geometry
#  4   B2        3000 non-null   float64
#  5   B3        3000 non-null   float64
#  6   B4        3000 non-null   float64
#  7   B8        3000 non-null   float64
# dtypes: float64(6), geometry(1), object(1)
# memory usage: 210.9+ KB

# %%
import pandas as pd
import numpy as np

def calculate_ndvi(df):
    """
    Calculate Normalized Difference Vegetation Index (NDVI) from a DataFrame.
    Requires bands 'B4' (Red) and 'B8' (NIR).
    """
    return (df['B8'] - df['B4']) / (df['B8'] + df['B4'])

def calculate_ndwi(df):
    """
    Calculate Normalized Difference Water Index (NDWI) from a DataFrame.
    Requires bands 'B3' (Green) and 'B8' (NIR).
    """
    return (df['B3'] - df['B8']) / (df['B3'] + df['B8'])

def calculate_evi(df):
    """
    Calculate Enhanced Vegetation Index (EVI) from a DataFrame.
    Requires bands 'B4' (Red), 'B8' (NIR), 'B2' (Blue), and constants C1, C2, L.
    """
    C1, C2, L = 6, 7.5, 1  # Adjust these constants as needed
    return (
        (df['B8'] - df['B4']) / (df['B8'] + C1 * df['B4'] - C2 * df['B2'] + L)
    ) * (1 + L)

def calculate_savi(df):
    """
    Calculate Soil-Adjusted Vegetation Index (SAVI) from a DataFrame.
    Requires bands 'B4' (Red), 'B8' (NIR), and a constant L.
    """
    L = 0.5  # Adjust this constant as needed
    return (
        ((df['B8'] - df['B4']) / (df['B8'] + df['B4'] + L)) * (1 + L)
    )

def calculate_gndvi(df):
    """
    Calculate Green Normalized Difference Vegetation Index (GNDVI) from a DataFrame.
    Requires bands 'B3' (Green) and 'B8' (NIR).
    """
    return (df['B8'] - df['B3']) / (df['B8'] + df['B3'])

def calculate_msavi2(df):
    """
    Calculate Modified Soil-Adjusted Vegetation Index (MSAVI2) from a DataFrame.
    Requires bands 'B4' (Red) and 'B8' (NIR).
    """
    return (
        (2 * df['B8'] + 1 - np.sqrt((2 * df['B8'] + 1)**2 - 8 * (df['B8'] - df['B4']))) / 2
    )

def calculate_pvi(df):
    """
    Calculate Perpendicular Vegetation Index (PVI) from a DataFrame.
    Requires bands 'B4' (Red) and 'B3' (Green).
    """
    return np.sqrt((df['B4']**2) + (df['B3']**2))

def calculate_vrpi(df):
    """
    Calculate Vegetation Ratio Index (VRPI) from a DataFrame.
    Requires bands 'B4' (Red) and 'B8' (NIR).
    """
    return df['B8'] / df['B4']

# %%
features_gdf['ndvi'] = features_gdf.apply(calculate_ndvi, axis=1)
features_gdf['ndwi'] = features_gdf.apply(calculate_ndwi, axis=1)
features_gdf['evi'] = features_gdf.apply(calculate_evi, axis=1)
features_gdf['savi'] = features_gdf.apply(calculate_savi, axis=1)
features_gdf['gndvi'] = features_gdf.apply(calculate_gndvi, axis=1)
features_gdf['msavi2'] = features_gdf.apply(calculate_msavi2, axis=1)
features_gdf['pvi'] = features_gdf.apply(calculate_pvi, axis=1)
features_gdf['vrpi'] = features_gdf.apply(calculate_vrpi, axis=1)

# %%
features_gdf.head()
# Out:
#                        Lat        Lon                      Country  \
# ID
# ID_SJ098E7S2SY9  34.162491  70.763668                  Afghanistan
# ID_CWCD60FGJJYY  32.075695  48.492047  Iran  (Islamic Republic of)
# ID_R1XF70RMVGL3  14.542826  33.313483                        Sudan
# ID_0ZBIDY0PEBVO  14.359480  33.284108                        Sudan
# ID_C20R2C0AYIT0  14.419128  33.528450                        Sudan
#
#                                   geometry        B2        B3        B4  \
# ID
# ID_SJ098E7S2SY9  POINT (70.76367 34.16249)  0.134978  0.183233  0.225967
# ID_CWCD60FGJJYY  POINT (48.49205 32.07570)  0.075088  0.109475  0.125675
# ID_R1XF70RMVGL3  POINT (33.31348 14.54283)  0.070991  0.111564  0.139091
# ID_0ZBIDY0PEBVO  POINT (33.28411 14.35948)  0.072600  0.111017  0.153167
# ID_C20R2C0AYIT0  POINT (33.52845 14.41913)  0.125548  0.180565  0.231452
#
#                        B8      ndvi      ndwi       evi      savi     gndvi  \
# ID
# ID_SJ098E7S2SY9  0.271456  0.091449 -0.194028  0.056336  0.068410  0.194028
# ID_CWCD60FGJJYY  0.275875  0.374051 -0.431815  0.204804  0.249903  0.431815
# ID_R1XF70RMVGL3  0.282891  0.340773 -0.434340  0.181451  0.233953  0.434340
# ID_0ZBIDY0PEBVO  0.204817  0.144280 -0.296992  0.065408  0.090299  0.296992
# ID_C20R2C0AYIT0  0.293478  0.118161 -0.238191  0.071270  0.090776  0.238191
#
#                    msavi2       pvi      vrpi
# ID
# ID_SJ098E7S2SY9  0.061409  0.290922  1.201308
# ID_CWCD60FGJJYY  0.226710  0.166670  2.195146
# ID_R1XF70RMVGL3  0.212524  0.178305  2.033856
# ID_0ZBIDY0PEBVO  0.077548  0.189169  1.337214
# ID_C20R2C0AYIT0  0.082454  0.293554  1.267987

# %%
# map countries to numbers
countries = features_gdf['Country'].unique()
countries_dict = {country: i for i, country in enumerate(countries)}
features_gdf['Country'] = features_gdf['Country'].map(countries_dict)
features_gdf.drop(columns=['geometry'], inplace=True)

# %%
features_gdf.to_csv('data/features.csv', index=True)

# %% [markdown]
# ## MODELING

# %%
import pandas as pd

# %%
features_gdf = pd.read_csv('data/features.csv', index_col='ID')
train_data = pd.read_csv('data/Train.csv', index_col='ID')
test_data = pd.read_csv('data/Test.csv', index_col='ID')
target = train_data['Target']

# %%
train_set = features_gdf[features_gdf.index.isin(train_data.index)]
test_set = features_gdf[features_gdf.index.isin(test_data.index)]

# %%
train_set.shape, test_set.shape
# Out:
# ((1500, 15), (1500, 15))

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Classification models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# Classification metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score

# %%
X_train, X_test, y_train, y_test = train_test_split(train_set, target, test_size=0.3, random_state=2040)

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
# Hyperparameter dictionaries using the specified pattern
logistic_regression_params = {
    'lr__penalty': ['l1', 'l2'],
    'lr__C': [0.001, 0.01, 0.1, 1, 10],
    'lr__solver': ['liblinear', 'saga'],
    'lr__max_iter': [100, 200, 300]
}

svc_params = {
    'svc__C': [0.1, 1, 10],
    'svc__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'svc__gamma': ['scale', 'auto', 0.1, 1],
    'svc__degree': [2, 3, 4],
}

random_forest_params = {
    'rf__n_estimators': [100, 200, 300],
    'rf__max_depth': [None, 10, 20, 30],
    'rf__min_samples_split': [2, 5, 10],
    'rf__min_samples_leaf': [1, 2, 4],
    'rf__max_features': ['auto', 'sqrt', 'log2']
}

gradient_boosting_params = {
    'gb__n_estimators': [50, 100, 200],
    'gb__learning_rate': [0.01, 0.1, 0.2],
    'gb__max_depth': [3, 4, 5],
    'gb__min_samples_split': [2, 3, 4],
    'gb__min_samples_leaf': [1, 2, 3],
}

k_neighbors_params = {
    'knn__n_neighbors': [3, 5, 7, 9],
    'knn__weights': ['uniform', 'distance'],
    'knn__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'knn__p': [1, 2],
}

decision_tree_params = {
    'dt__criterion': ['gini', 'entropy'],
    'dt__max_depth': [None, 10, 20, 30],
    'dt__min_samples_split': [2, 5, 10],
    'dt__min_samples_leaf': [1, 2, 4],
    'dt__max_features': ['auto', 'sqrt', 'log2'],
}

# %%
#Map models to their hyperparameters into a dataframe
models_hyperparameters = pd.DataFrame({
    'names': ['lr', 'svc', 'rf', 'gb', 'knn', 'dt'],
    'model': [LogisticRegression(), SVC(), RandomForestClassifier(), GradientBoostingClassifier(), KNeighborsClassifier(), DecisionTreeClassifier()],
    'hyperparameters': [logistic_regression_params, svc_params, random_forest_params, gradient_boosting_params, k_neighbors_params, decision_tree_params]
})

# %%
def model_pipeline_grid(model_name, model, params):
  print("Model:", model_name)
  pipe = Pipeline([('scaler', StandardScaler()), (model_name, model)])
  grid = GridSearchCV(pipe, params, cv=5, scoring='accuracy', n_jobs=-1)
  grid.fit(X_train, y_train)
  print('Best parameters:', grid.best_params_)
  print('Best score:', grid.best_score_)
  print('Test score:', grid.score(X_test, y_test))
  grid_pred = grid.predict(X_test)
  print('Classification report:\n', classification_report(y_test, grid_pred))
  # return classification_report(y_test, grid_pred, output_dict=True)

# %%
model_pipeline_grid('lr', LogisticRegression(), logistic_regression_params)
# Out:
# Model: lr
# Best parameters: {'lr__C': 10, 'lr__max_iter': 100, 'lr__penalty': 'l1', 'lr__solver': 'liblinear'}
# Best score: 0.7685714285714285
# Test score: 0.7511111111111111
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.82      0.75       205
#            1       0.82      0.69      0.75       245
#
#     accuracy                           0.75       450
#    macro avg       0.76      0.76      0.75       450
# weighted avg       0.76      0.75      0.75       450

# %%
model_pipeline_grid('svc', SVC(), svc_params)
# Out:
# Model: svc

# %%
model_pipeline_grid('rf', RandomForestClassifier(), random_forest_params)
# Out:
# Model: rf
# Best parameters: {'rf__max_depth': 20, 'rf__max_features': 'log2', 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 10, 'rf__n_estimators': 200}
# Best score: 0.8161904761904764
# Test score: 0.8133333333333334
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80       205
#            1       0.86      0.79      0.82       245
#
#     accuracy                           0.81       450
#    macro avg       0.81      0.82      0.81       450
# weighted avg       0.82      0.81      0.81       450

# %%
model_pipeline_grid('gb', GradientBoostingClassifier(), gradient_boosting_params)
# Out:
# Model: gb
# Best parameters: {'gb__learning_rate': 0.2, 'gb__max_depth': 5, 'gb__min_samples_leaf': 1, 'gb__min_samples_split': 3, 'gb__n_estimators': 50}
# Best score: 0.8371428571428572
# Test score: 0.8244444444444444
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81       205
#            1       0.86      0.80      0.83       245
#
#     accuracy                           0.82       450
#    macro avg       0.82      0.83      0.82       450
# weighted avg       0.83      0.82      0.82       450

# %%
model_pipeline_grid('knn', KNeighborsClassifier(), k_neighbors_params)
# Out:
# Model: knn
# Best parameters: {'knn__algorithm': 'auto', 'knn__n_neighbors': 9, 'knn__p': 2, 'knn__weights': 'distance'}
# Best score: 0.7780952380952382
# Test score: 0.7866666666666666
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78       205
#            1       0.83      0.76      0.79       245
#
#     accuracy                           0.79       450
#    macro avg       0.79      0.79      0.79       450
# weighted avg       0.79      0.79      0.79       450

# %%
model_pipeline_grid('dt', DecisionTreeClassifier(), decision_tree_params)
# Out:
# Model: dt
# Best parameters: {'dt__criterion': 'gini', 'dt__max_depth': 20, 'dt__max_features': 'sqrt', 'dt__min_samples_leaf': 2, 'dt__min_samples_split': 10}
# Best score: 0.780952380952381
# Test score: 0.74
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.79      0.73       205
#            1       0.80      0.70      0.75       245
#
#     accuracy                           0.74       450
#    macro avg       0.74      0.74      0.74       450
# weighted avg       0.75      0.74      0.74       450

# %% [markdown]
# ## SELECTED MODEL

# %%
from sklearn.ensemble import GradientBoostingClassifier
# {'gb__learning_rate': 0.2, 'gb__max_depth': 5, 'gb__min_samples_leaf': 1, 'gb__min_samples_split': 3, 'gb__n_estimators': 50}
gb = GradientBoostingClassifier(n_estimators=50, learning_rate=0.2, max_depth=5, min_samples_split=3, min_samples_leaf=1)
gb.fit(train_set, target)
preds = gb.predict(test_set)

# %%
import pickle
pickle.dump(gb, open('models/gradiendBoost_v1.pkl', 'wb'))

# %%
df = pd.DataFrame({'ID': test_set.index, 'Target': preds})
df.to_csv('data/submission.csv', index=False)

# %% [markdown]
# ## ENSEMBLERS

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216 from C header, got 232 from PyObject

# %%
# Hyperparameter dictionaries using the specified pattern
xgb_params = {
    'xgb__n_estimators': [50, 100, 200],
    'xgb__learning_rate': [0.01, 0.1, 0.2],
    'xgb__max_depth': [3, 4, 5],
    'xgb__min_child_weight': [1, 2, 3],
    'xgb__gamma': [0, 0.1, 0.2],
    'xgb__subsample': [0.5, 0.6, 0.7],
    'xgb__colsample_bytree': [0.5, 0.6, 0.7],
    'xgb__objective': ['multi:softmax', 'multi:softprob'],
    'xgb__num_class': [1, 2, 3, 4]
}
lgbm_params = {
    'lgbm__n_estimators': [50, 100, 200],
    'lgbm__learning_rate': [0.01, 0.1, 0.2],
    'lgbm__max_depth': [3, 4, 5],
    'lgbm__num_leaves': [31, 62, 93],
    'lgbm__min_child_samples': [20, 40, 60],
    'lgbm__subsample': [0.5, 0.6, 0.7],
    'lgbm__colsample_bytree': [0.5, 0.6, 0.7],
    'lgbm__objective': ['multiclass'],
    'lgbm__num_class': [1, 2, 3, 4]
}

catboost_params = {
    'cat__iterations': [50, 100, 200],
    'cat__learning_rate': [0.01, 0.1, 0.2],
    'cat__depth': [3, 4, 5],
    'cat__l2_leaf_reg': [1, 3, 5],
    'cat__border_count': [5, 10, 20],
    'cat__ctr_border_count': [5, 10, 20],
    'cat__thread_count': [2, 4, 6],
    'cat__objective': ['MultiClass'],
    'cat__num_class': [1, 2, 3, 4]
}

# %%
# Evaluate xgboost
model_pipeline_grid('xgb', XGBClassifier(), xgb_params)
# Out:
# Model: xgb
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\roywa\ZINDI\Geo-ai\geo_ai_pre.ipynb Cell 52 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y150sZmlsZQ%3D%3D?line=0'>1</a> # Evaluate xgboost
# ----> <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y150sZmlsZQ%3D%3D?line=1'>2</a> model_pipeline_grid('xgb', XGBClassifier(), xgb_params)
#
# c:\Users\roywa\ZINDI\Geo-ai\geo_ai_pre.ipynb Cell 52 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y150sZmlsZQ%3D%3D?line=2'>3</a> pipe = Pipeline([('scaler', StandardScaler()), (model_name, model)])
#       <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y150sZmlsZQ%3D%3D?line=3'>4</a> grid = GridSearchCV(pipe, params, cv=5, scoring='accuracy', n_jobs=-1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y150sZmlsZQ%3D%3D?line=4'>5</a> grid.fit(X_train, y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y150sZmlsZQ%3D%3D?line=5'>6</a> print('Best parameters:', grid.best_params_)
#       <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y150sZmlsZQ%3D%3D?line=6'>7</a> print('Best score:', grid.best_score_)
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
model_pipeline_grid('lgbm', LGBMClassifier(), lgbm_params)
# Out:
# Model: lgbm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\roywa\ZINDI\Geo-ai\geo_ai_pre.ipynb Cell 53 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y151sZmlsZQ%3D%3D?line=0'>1</a> model_pipeline_grid('lgbm', LGBMClassifier(), lgbm_params)
#
# c:\Users\roywa\ZINDI\Geo-ai\geo_ai_pre.ipynb Cell 53 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y151sZmlsZQ%3D%3D?line=2'>3</a> pipe = Pipeline([('scaler', StandardScaler()), (model_name, model)])
#       <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y151sZmlsZQ%3D%3D?line=3'>4</a> grid = GridSearchCV(pipe, params, cv=5, scoring='accuracy', n_jobs=-1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y151sZmlsZQ%3D%3D?line=4'>5</a> grid.fit(X_train, y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y151sZmlsZQ%3D%3D?line=5'>6</a> print('Best parameters:', grid.best_params_)
#       <a href='vscode-notebook-cell:/c%3A/Users/roywa/ZINDI/Geo-ai/geo_ai_pre.ipynb#Y151sZmlsZQ%3D%3D?line=6'>7</a> print('Best score:', grid.best_score_)
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\roywa\mambaforge\envs\zindi\Lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
model_pipeline_grid('cat', CatBoostClassifier(), catboost_params)
